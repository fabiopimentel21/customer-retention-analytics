# %%
import pandas as pd
alarme = pd.read_csv(r'C:\Users\devma\Projetos\customer-retention-analytics\analise-churn-produtos\alarme.csv', sep=',')
alarme
# Out:
#      periodo  clientes_no_inicio_do_mes  total_churn_no_mes  \
# 0    2003-07                          6                   0
# 1    2003-08                         13                   0
# 2    2003-09                         22                   0
# 3    2003-10                         34                   0
# 4    2003-11                         51                   1
# ..       ...                        ...                 ...
# 268  2025-11                       3778                  25
# 269  2025-12                       3768                  40
# 270  2026-01                       3755                  37
# 271  2026-02                       3752                  39
# 272  2026-03                       3744                  12
#
#      churn_rate_percentual status_saude
# 0                     0.00     SAUDÁVEL
# 1                     0.00     SAUDÁVEL
# 2                     0.00     SAUDÁVEL
# 3                     0.00     SAUDÁVEL
# ...
